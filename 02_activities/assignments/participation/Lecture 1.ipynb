# %% [markdown]
# Graph Example Activity
#
# **Activity (Life Expectancy: 2007)**
#
# o Is the visualization pleasing to look at?
#     - Overall, yes, but the 3D effect is hard to look at, shadows do not make sense.
#
# o Does the visualization accurately represent data?
#     - No, 3D bars unnecessary, axis are unclear, hard to distinguish where the bar ends, legend is not needed as it is a little repetitive, no source information.
#
# o Can we understand what message the maker of the visualization is attempting to convey?
#     - No, do not know if life expectancy is for everyone or certain population (health related). Numbers are hard to decipher.
#
# o Consider factors such as colour, size, use of images. Is this a ‘good’ data visualization? Why or why not?
#     - No, colours are good but the 3D effect makes it difficult to look at.
#
# **Activity (Monstrous Costs)**
#
# o	Is the visualization pleasing to look at?
#     - Yes, very creative but a little over the top, not professional in all settings, hard to read the angled data format.
#
# o Does the visualization accurately represent data?
#     - No, axis title unclear and no scale. Not sure which political party is represented.
#
# o Can we understand what message the maker of the visualization is attempting to convey?
#     - Not fully, understand generally but not the most clear.
#
# o Consider factors such as colour, size, use of images. Is this a ‘good’ data visualization? Why or why not?
#     - No, could be more accurate and not as over the top.
#
# **Activity (Aspect Ratios)**
#
# o Is the visualization pleasing to look at?
#     - Yes, very clean and organized but content is not accurate.
#
# o Does the visualization accurately represent data?
#     - No, unclear what data is being presented, no axis titles. Effect is visualized differently depending on aspect ratio presentation, message changes. No source for data. No legend so no comparative value.
#
# o Can we understand what message the maker of the visualization is attempting to convey?
#     - No.
#
# o	Consider factors such as colour, size, use of images. Is this a ‘good’ data visualization? Why or why not?
#     - No, there is no distinction between the two data points.
#
# **Activity (2012 Presidential Run)**
#
# o Is the visualization pleasing to look at?
#     - No, very disorganized, shine glass effect. Proportions do not represent the percentage sizes.
#
# o Does the visualization accurately represent data?
#     - No, unclear what data is being presented, do not understand labels. Source for data is questionable – who is opinions? What do the percentages represent, percentages exceed 100%. What is GOP in short form?
#
# o Can we understand what message the maker of the visualization is attempting to convey?
#     - No, very unclear.
#
# o Consider factors such as colour, size, use of images. Is this a ‘good’ data visualization? Why or why not?
#     - No, everything is not proportional.
#
# **Activity (Wind Map)**
#
# o Is the visualization pleasing to look at?
#     - Yes, very nice. Contrast had to distinguish for different speeds.
#
# o Does the visualization accurately represent data?
#     - Yes, date is included.
#
# o Can we understand what message the maker of the visualization is attempting to convey?
#     - Yes, very clear.
#
# o Consider factors such as colour, size, use of images. Is this a ‘good’ data visualization? Why or why not?
#     - Some improvements could be made with colours.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(y)
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc='center')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y, marker='*', color = "indigo")

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y, marker='*', color = 'indigo', linestyle = '--', linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*', markersize = 12, color = '#7425b9', linestyle = '--', linewidth = 2, markeredgecolor = '#fa9359', markerfacecolor = '#000000' )

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.grid(axis = 'y', color = "blue", linewidth = 2, linestyle = '-.')
ax.plot(x,y,marker='*', markersize = 12, color = '#7425b9', linestyle = '--', linewidth = 2, markeredgecolor = '#fa9359', markerfacecolor = '#000000' )
