# %% [markdown]
# **Brooks Diagram Activity**
#
# - How did this diagram of the Brooks use rational, moral and emotional appeal to make a case to its audience?
#
# Rational: used keywords and descriptions, very specific number of peoples, some type of quantitative data and facts about the space
#
# Moral: used schematic of how people moved/crawled through the ship which shows inhuman conditions, lloking at different imaging perspectives
#
# Emotional: we can see the inhuman conditions from the ship visualizations which brings strong feelings of injustice, feeling of right vs. wrong, evokes anger as we can put ourselves in their shoes

# %% [markdown]
#  **Pulse Activity**
#
#  - How does it challenge our assumption about what a visualization can look like? What are the strengths and weaknesses of this example?
#
# It is very attention striking, no legends or data source so a little hard for us to interpret what is going on. Data is hard to understand what they want us to see. Hard to reproduce. Data is static, might not be suitable for large datasets.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('dark')
sns.lineplot(data=tips, # choose our dataset
x='total_bill', # define our x variable
y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tipgraph = sns.lineplot(data=tips, x='total_bill',y='tip')
tipgraph.set(title='Tips vs. Total Bill', xlabel='Total Bill ($)', ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.lineplot(data=tips,x='total_bill', y='tip', color = 'hotpink', linestyle = '--',linewidth = 3,marker = 'o',markerfacecolor = 'indigo')

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',y='tip', style = 'time', hue ='day', palette = ['purple','hotpink','deepskyblue','yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill',xlabel='Total Bill ($)',ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(data = tips, hue = 'day')

# %%
daysplot = sns.relplot(data=tips, #creates relational plots and specifies the dataframe containing the data
                       x="total_bill", #maps the x-axis
                       y="tip", #maps the y-axis
                       hue="sex", #colours male vs female and adds a legend
                       col="day", #creates unique panels for each of the seperate days 
                       kind="scatter", #defines that graph is a scatter plot
                       col_wrap=2) #gives a 2x2 arrangement inside of 4 plots in one row

# %% [markdown]
# **Comparing Data Visualizations Activity**
#
# - How are they different? What does each visualization do?
#
# Graph on the left is more static where the one on the right is more dynamic. Left graph has a small sample size, covers a specific group of people with specific counts. The right graph is more overall.
#
# - What are the pros and cons of each?
#
# The right graph has a larger data set, contains more conclusions and more information. Easier to understand but counts not as accurate. It also allows more freedom to explore. It can also be more subjective in interpretation depending on the word used.
#
# The left graph requires even less cognitive load, it is descriptive and more accurate than the right graph.
#
# **Types of Changes Activity**
#
# - What types of changes occur when we interact with this dynamic data visualization?
#
# Could be translational or immediate.
#
# - Which spatial and retinal elements stay constant? Which change?
#
# Points and frequency spatially change, the colours (retinal) stays the same.
#
# - If you were redesigning this viz, would you
# choose to make different changes? Why or
# why not?
#
# Reordering of disciplines could be different for more direct comparisons across words.

# %%
import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy","Zoro","Nami","Usopp","Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

graph = go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1))

# %%
graph.update_layout(title="Pirate Scores",
                    xaxis_title="Pirates",
                    yaxis_title="Score")
graph.show()

# %%
graph.write_html("pirategraph.html")

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', # we want points for a scatter plot
marker=dict(size=15, # point size
color='hotpink', # point colour
opacity=1, # point transparency/alpha
line=dict(width=5, color='purple')))) # point outline
graph.update_layout(title='Interactive Pirate Plot',xaxis_title='Pirates',yaxis_title='Scores',width=500, height=500)

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)
# generate our wordcloud image
wordcloud = WordCloud(background_color="white", colormap = 'inferno').generate(text) # use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, # remember 'imshow' from when we added pictures to our matplotlib axes
interpolation='bilinear') # this line helps smooth our image
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
# !pip install matplotlib-venn
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45440 sha256=71c77664bc01c99265f864a80a82b5c6b50324bd7402c43047b0f40087fa988b
#   Stored in directory: c:\users\steph\appdata\local\pip\cache\wheels\d1\5f\e6\771479559f992b8398265ebf61f8a3d33ca0b8f75552e06ad2
# Successfully built matplotlib-venn
# ...

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
A = set(["apple","banana","watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])

# %%
diagram = venn2_unweighted([A, B],set_labels = ('Fruits','Pies'),set_colors=("blue","red"),alpha=0.5)
plt.show()
# Out:
# c:\Users\steph\anaconda3\Lib\site-packages\matplotlib_venn\_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.

# %%
A = set(["apple","banana","watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])
diagram = venn2_unweighted([A, B],set_labels = ('Fruits','Pies'),set_colors=("blue","red"),alpha=0.5)

diagram.get_label_by_id("10").set_text("\n".join(A - B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))
plt.show()
