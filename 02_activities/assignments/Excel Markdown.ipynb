# %% [markdown]
# What software did you use to create your data visualization?
#
# - I used excel to create my data visualization.
#
# Who is your intended audience?
#
# - General public or citizens of Toronto who are familiar or know about the Toronto Island Ferry. Have no prior technicial or background knowledge.
#
# What information or message are you trying to convey with your visualization?
#
# - I want to convey how ferry ridership (through ticket sales and redemption) changed year to year and how a major event like COVID-19 in 2020 impacted the pattern.
#
# What aspects of design did you consider when making your visualization? How did you apply them? With what elements of your plots?
#
# - For both visualizations I wanted to make it simple and really clear to read. I used two distinct and clear colours that are colour-blind friendly (blue and orange) as well as having a clear legend, clear axis titles and numbers. I also used fonts and typefaces that are easy to read. Although the excel visualization is clear and understandable, I do think the python visualization is easier to visualize and see trends, espeically in 2020 with COVID-19.
#
# How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
#
# - The excel visualization is not as reproducible as it requires some reformatting of the Timestamp column using excel formulas to just display the year and a prior unerstanding of pivot charts and pivot graphs. Without this understanding, it can be quite difficult to reproduce the graphs. But, once this knowledge is gained, it is easy to use the excel file and plug/play the reuqired data points into the chart. Changing the formatting can also be an issue as there is a default design that needs to be changed.
#
# How did you ensure that your data visualization is accessible?
#
# - I used colourblind-friendly colours (blue and orange) that were also bright, I labelled axes clearly with readbale font sizes and I could improve further by adding alt-text.
#
# Who are the individuals and communities who might be impacted by your visualization?
#
# - Some individuals and communities include ferry commuters and tourists for service freqeuncy and availbility, city planners for infrastructure and planning and busnisses on the island which could impact sales and foot traffic.
#
# How did you choose which features of your chosen dataset to include or exclude from your visualization?
#
# - Included important metrics to understand the ridership which was timestamp (year), sales count and redemptions count. The id column was just a row number and had no meaning so I excluded this.
#
# What ‘underwater labour’ contributed to your final data visualization product?
#
# - Some of the aspects that were hidden work was realizing that the Timestamp column in the CSV was stored as  text so it had to be reformatted, I decied to aggregate into yearly totals, choosing an appropriate scale and also deciding on clean and concise designs for easy readability.
